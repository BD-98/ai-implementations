# %%
# %pylab inline 
import torch 
import torch.nn as nn 
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid 
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Load Data 
root = "~/coding/learning/ai-implementations/datasets/pokemon"
tensor = transforms.ToTensor()
imnet_root = "~/coding/learning/ai-implementations/datasets/pokemon"
trainset = datasets.ImageFolder(root, transform=tensor)
data = DataLoader(trainset, shuffle=True, batch_size=16)
imagenet = datasets.ImageNet(root=imnet_root, download=True, transform=tensor)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-d2c1ad304ad6> in <module>
#       5 trainset = datasets.ImageFolder(root, transform=tensor)
#       6 data = DataLoader(trainset, shuffle=True, batch_size=16)
# ----> 7 imagenet = datasets.ImageNet(root=imnet_root, download=True, transform=tensor)
#
# ~/.local/lib/python3.8/site-packages/torchvision/datasets/imagenet.py in __init__(self, root, split, download, **kwargs)
#      44                    "download the archives externally and place them in the root "
#      45                    "directory.")
# ---> 46             raise RuntimeError(msg)
#      47         elif download is False:
#      48             msg = ("The use of the download flag is deprecated, since the dataset "
#
# ...

# %%
# Stylegan 2 inspired Model refer to: https://arxiv.org/abs/1912.04958

# Refer to section 4.2 ProGan paper: https://arxiv.org/abs/1710.10196
class PixelNorm(nn.Module):
    def __init__(self):
        super(PixelNormLayer, self).__init__()

    def forward(self, x):
        return x * torch.rsqrt(torch.mean(x ** 2, dim=1, keepdim=True) + 1e-8)

    def __repr__(self):
        return self.__class__.__name__


class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            # Starts at 512 X 1 X 1
            nn.ConvTranspose2d(512, 512, kernel_size=4), # 512 X 4 X 4 
            nn.LeakyReLU(0.2, inplace=True),
            # 512 X 4 X 4 
            nn.Conv2d(512, 512, kernel_size=4), 
            nn.LeakyReLU(0.2, inplace=True),
            PixelNorm(),
            # 512 X 8 X 8 
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.


        )
